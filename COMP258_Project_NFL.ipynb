# %% [markdown]
# ## GROUP 1 - NFL PREDICTOR

# %%
import numpy as np
import pandas as pd

# %%
scores = pd.read_csv('spreadspoke_scores.csv')
teams = pd.read_csv('nfl_teams.csv')
# stadiums = pd.read_csv('nfl_stadiums.csv')

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13232 entries, 0 to 13231
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        13232 non-null  object
#  1   schedule_season      13232 non-null  int64
#  2   schedule_week        13232 non-null  object
#  3   schedule_playoff     13232 non-null  bool
#  4   team_home            13232 non-null  object
#  5   score_home           13231 non-null  float64
#  6   score_away           13231 non-null  float64
#  7   team_away            13232 non-null  object
#  8   team_favorite_id     10753 non-null  object
#  9   spread_favorite      10753 non-null  float64
#  10  over_under_line      10743 non-null  object
#  11  stadium              13232 non-null  object
#  12  stadium_neutral      13232 non-null  bool
#  13  weather_temperature  12189 non-null  float64
#  14  weather_wind_mph     12172 non-null  float64
#  15  weather_humidity     8441 non-null   float64
#  16  weather_detail       2822 non-null   object
# dtypes: bool(2), float64(6), int64(1), object(8)
# memory usage: 1.5+ MB

# %%
scores.sort_values(by='schedule_season', ascending=False, inplace=True)
scores.head()
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 13231     2/13/2022             2021     Superbowl              True
# 13044    10/24/2021             2021             7             False
# 13038    10/17/2021             2021             6             False
# 13039    10/17/2021             2021             6             False
# 13040    10/18/2021             2021             6             False
#
#                       team_home  score_home  score_away  \
# 13231          Los Angeles Rams         NaN         NaN
# 13044         Green Bay Packers        24.0        10.0
# 13038       Pittsburgh Steelers        23.0        20.0
# 13039  Washington Football Team        13.0        31.0
# 13040          Tennessee Titans        34.0        31.0
#
#                       team_away team_favorite_id  spread_favorite  \
# 13231        Cincinnati Bengals              LAR             -4.0
# 13044  Washington Football Team               GB             -8.5
# 13038          Seattle Seahawks              PIT             -5.5
# 13039        Kansas City Chiefs               KC             -6.5
# 13040             Buffalo Bills              BUF             -6.0
#
#       over_under_line         stadium  stadium_neutral  weather_temperature  \
# 13231            48.5    SoFi Stadium             True                 72.0
# 13044              48   Lambeau Field            False                  NaN
# 13038              43     Heinz Field            False                  NaN
# 13039              54     FedEx Field            False                  NaN
# 13040            53.5  Nissan Stadium            False                  NaN
#
#        weather_wind_mph  weather_humidity weather_detail
# 13231               0.0               NaN           DOME
# 13044               NaN               NaN            NaN
# 13038               NaN               NaN            NaN
# 13039               NaN               NaN            NaN
# 13040               NaN               NaN            NaN

# %%
scores.schedule_week.unique()
# Out:
# array(['Superbowl', '7', '6', '5', '8', '9', '10', '2', '1', '3', '4',
#        '17', '16', '15', 'Wildcard', '18', 'Division', 'Conference', '12',
#        '11', '14', '13', 'SuperBowl', 'WildCard'], dtype=object)

# %%
teams.info()
# teams
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   team_name                43 non-null     object
#  1   team_name_short          43 non-null     object
#  2   team_id                  43 non-null     object
#  3   team_id_pfr              43 non-null     object
#  4   team_conference          43 non-null     object
#  5   team_division            34 non-null     object
#  6   team_conference_pre2002  43 non-null     object
#  7   team_division_pre2002    41 non-null     object
# dtypes: object(8)
# memory usage: 2.8+ KB

# %%
###
# CREATE OFFICIAL TEAMS COLLECTION
### 

invalid_teams_idx = teams[teams['team_division'].isna()].index
invalid_teams_idx = invalid_teams_idx.append(pd.Index([20,42]))
print(invalid_teams_idx)
teams.drop(index=invalid_teams_idx, inplace=True)
display(teams)
print(len(teams))
# Out:
# Int64Index([1, 2, 15, 22, 26, 30, 31, 38, 39, 20, 42], dtype='int64')
#                team_name team_name_short team_id team_id_pfr team_conference  \
# 0      Arizona Cardinals       Cardinals     ARI         CRD             NFC
# 3        Atlanta Falcons         Falcons     ATL         ATL             NFC
# 4       Baltimore Ravens          Ravens     BAL         RAV             AFC
# 5          Buffalo Bills           Bills     BUF         BUF             AFC
# 6      Carolina Panthers        Panthers     CAR         CAR             NFC
# 7          Chicago Bears           Bears     CHI         CHI             NFC
# 8     Cincinnati Bengals         Bengals     CIN         CIN             AFC
# 9       Cleveland Browns          Browns     CLE         CLE             AFC
# 10        Dallas Cowboys         Cowboys     DAL         DAL             NFC
# 11        Denver Broncos         Broncos     DEN         DEN             AFC
# 12         Detroit Lions           Lions     DET         DET             NFC
# 13     Green Bay Packers         Packers      GB         GNB             NFC
# 14        Houston Texans          Texans     HOU         HTX             AFC
# 16    Indianapolis Colts           Colts     IND         CLT             AFC
# 17  Jacksonville Jaguars         Jaguars     JAX         JAX             AFC
# 18    Kansas City Chiefs          Chiefs      KC         KAN             AFC
# 19  Los Angeles Chargers        Chargers     LAC         SDG             AFC
# 21      Los Angeles Rams            Rams     LAR         RAM             NFC
# 23        Miami Dolphins        Dolphins     MIA         MIA             AFC
# 24     Minnesota Vikings         Vikings     MIN         MIN             NFC
# 25  New England Patriots        Patriots      NE         NWE             AFC
# 27    New Orleans Saints          Saints      NO         NOR             NFC
# 28       New York Giants          Giants     NYG         NYG             NFC
# 29         New York Jets            Jets     NYJ         NYJ             NFC
# 32       Oakland Raiders         Raiders     LVR         RAI             AFC
# 33   Philadelphia Eagles          Eagles     PHI         PHI             NFC
# 34   Pittsburgh Steelers        Steelers     PIT         PIT             AFC
# 35      Seattle Seahawks        Seahawks     SEA         SEA             NFC
# 36   San Francisco 49ers           49ers      SF         SFO             NFC
# 37  Tampa Bay Buccaneers      Buccaneers      TB         TAM             NFC
# 40      Tennessee Titans          Titans     TEN         OTI             AFC
# 41   Washington Redskins      Washington     WAS         WAS             NFC
#
#    team_division team_conference_pre2002 team_division_pre2002
# 0       NFC West                     NFC              NFC West
# 3      NFC South                     NFC              NFC West
# 4      AFC North                     AFC           AFC Central
# 5       AFC East                     AFC              AFC East
# 6      NFC South                     NFC              NFC West
# 7      NFC North                     NFC           NFC Central
# 8      AFC North                     AFC           AFC Central
# 9      AFC North                     AFC           AFC Central
# 10      NFC East                     NFC              NFC East
# 11      AFC West                     AFC              AFC West
# 12     NFC North                     NFC           NFC Central
# 13     NFC North                     NFC           NFC Central
# 14     AFC South                     AFC                   NaN
# 16     AFC South                     AFC              AFC East
# 17     AFC South                     AFC           AFC Central
# 18      AFC West                     AFC              AFC West
# 19      AFC West                     AFC              AFC West
# 21      NFC West                     NFC              NFC West
# 23      AFC East                     AFC              AFC East
# 24     NFC North                     NFC           NFC Central
# 25      AFC East                     AFC              AFC East
# 27     NFC South                     NFC              NFC West
# 28      NFC East                     NFC              NFC East
# 29      AFC East                     NFC              AFC East
# 32      AFC West                     AFC              AFC West
# 33      NFC East                     NFC              NFC East
# 34     AFC North                     AFC           AFC Central
# 35      NFC West                     AFC              AFC West
# 36      NFC West                     NFC              NFC West
# 37     NFC South                     NFC           NFC Central
# 40     AFC South                     AFC           AFC Central
# 41      NFC East                     NFC              NFC East
# 32

# %%
scores.columns
['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
       'team_home', 'score_home', 'score_away', 'team_away',
       'team_favorite_id', 'spread_favorite', 'over_under_line', 'stadium',
       'stadium_neutral', 'weather_temperature', 'weather_wind_mph',
       'weather_humidity', 'weather_detail']

data = scores[['schedule_week', 'schedule_playoff','team_home', 'score_home', 'score_away', 'team_away']]
# data.info()

# %%
data[data['score_home'].isnull()]
# Special Case Superbowl 2021
# Out:
#       schedule_week  schedule_playoff         team_home  score_home  \
# 13231     Superbowl              True  Los Angeles Rams         NaN
#
#        score_away           team_away
# 13231         NaN  Cincinnati Bengals

# %% [markdown]
# ## Preprocessing

# %%
display(data)
data.info()
# Out:
#       schedule_week  schedule_playoff                 team_home  score_home  \
# 13231     Superbowl              True          Los Angeles Rams         NaN
# 13044             7             False         Green Bay Packers        24.0
# 13038             6             False       Pittsburgh Steelers        23.0
# 13039             6             False  Washington Football Team        13.0
# 13040             6             False          Tennessee Titans        34.0
# ...             ...               ...                       ...         ...
# 114              12             False            Denver Broncos         3.0
# 113              11             False          Cleveland Browns        14.0
# 112              10             False       Washington Redskins        30.0
# 111              11             False        San Diego Chargers        19.0
# 0                 1             False            Miami Dolphins        14.0
#
#        score_away                 team_away
# 13231         NaN        Cincinnati Bengals
# 13044        10.0  Washington Football Team
# 13038        20.0          Seattle Seahawks
# 13039        31.0        Kansas City Chiefs
# 13040        31.0             Buffalo Bills
# ...           ...                       ...
# 114          17.0           Oakland Raiders
# 113           3.0       Washington Redskins
# 112          31.0            Dallas Cowboys
# 111          41.0           Oakland Raiders
# 0            23.0           Oakland Raiders
#
# [13232 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13232 entries, 13231 to 0
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   schedule_week     13232 non-null  object
#  1   schedule_playoff  13232 non-null  bool
#  2   team_home         13232 non-null  object
#  3   score_home        13231 non-null  float64
#  4   score_away        13231 non-null  float64
#  5   team_away         13232 non-null  object
# dtypes: bool(1), float64(2), object(3)
# memory usage: 633.2+ KB

# %%
# Remove rows without scores
data = data.dropna(subset=['score_home', 'score_away'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13231 entries, 13044 to 0
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   schedule_week     13231 non-null  object
#  1   schedule_playoff  13231 non-null  bool
#  2   team_home         13231 non-null  object
#  3   score_home        13231 non-null  float64
#  4   score_away        13231 non-null  float64
#  5   team_away         13231 non-null  object
# dtypes: bool(1), float64(2), object(3)
# memory usage: 633.1+ KB

# %%
###
# FIX DUPLICATE LABELS IN SCHEDULE_WEEK
### 

data['schedule_week'] = data['schedule_week'].apply(lambda x: str(x).lower())
data['schedule_week'].unique()
# Out:
# array(['7', '6', '5', '8', '9', '10', '2', '1', '3', '4', '17', '16',
#        '15', 'wildcard', '18', 'division', 'conference', '12', '11', '14',
#        '13', 'superbowl'], dtype=object)

# %%
###
# REMOVE SCORES NOT IN THE OFFICIAL TEAM COLLECTION
### 

valid_teams = teams['team_name'].unique()
# len(valid_teams)

invalid_scores = data[(~data['team_home'].isin(valid_teams) | ~data['team_away'].isin(valid_teams))]
print(f'Total original scores: {len(data)}')
print(f'Total invalid scores: {len(invalid_scores)}')
data.drop(index=invalid_scores.index, inplace=True)
print(f'Total final scores: {len(data)}')
# Out:
# Total original scores: 13231
# Total invalid scores: 2563
# Total final scores: 10668

# %%
# Label encoding for team names and schedule week
from sklearn.preprocessing import LabelEncoder

# Keep original data
prep_data = []
prep_data = data.copy()

# team_label_encoder = LabelEncoder()
# schedule_encoder = LabelEncoder()

# # build a set with all the teams
# teams = {}
# teams = set(prep_data['team_home'].unique())
# teams.update(set(prep_data['team_away'].unique()))

# # Encondign Teams
# team_label_encoder.fit(list(teams))
# prep_data['team_home'] = team_label_encoder.transform(prep_data['team_home'])
# prep_data['team_away'] = team_label_encoder.transform(prep_data['team_away'])

# # Encoding Schedule
# schedule_encoder.fit(prep_data['schedule_week'])
# prep_data['schedule_week'] = schedule_encoder.transform(prep_data['schedule_week'])


# display(prep_data)
# print(schedule_encoder.classes_)
# x = schedule_encoder.inverse_transform([0,2,19,20])
# x

# %%
# Create label
def create_label(row):
    if row['score_home'] != None and row['score_away'] != None:
        if row['score_home'] > row['score_away']:
            return 1
        else:
            return 0

prep_data['label'] = prep_data.apply(lambda x: create_label(x), axis=1)
prep_data.drop(['score_home','score_away'], inplace= True, axis=1)

# Codify schedule play off
def code_schedule_playoff(row):
    if row['schedule_playoff'] == True:
        return 1
    else:
        return 0

prep_data['playoff'] = prep_data.apply(lambda x: code_schedule_playoff(x), axis=1)
prep_data.drop(['schedule_playoff'], inplace= True, axis=1)    
display(prep_data)
print(prep_data.playoff.value_counts())
print(prep_data.columns)
# Out:
#       schedule_week            team_home            team_away  label  playoff
# 13038             6  Pittsburgh Steelers     Seattle Seahawks      1        0
# 13040             6     Tennessee Titans        Buffalo Bills      1        0
# 13041             7     Cleveland Browns       Denver Broncos      1        0
# 13042             7    Arizona Cardinals       Houston Texans      1        0
# 13043             7     Baltimore Ravens   Cincinnati Bengals      0        0
# ...             ...                  ...                  ...    ...      ...
# 116              11    Green Bay Packers        Chicago Bears      1        0
# 114              12       Denver Broncos      Oakland Raiders      0        0
# 113              11     Cleveland Browns  Washington Redskins      1        0
# 112              10  Washington Redskins       Dallas Cowboys      0        0
# 0                 1       Miami Dolphins      Oakland Raiders      0        0
#
# [10668 rows x 5 columns]
# 0    10201
# 1      467
# Name: playoff, dtype: int64
# Index(['schedule_week', 'team_home', 'team_away', 'label', 'playoff'], dtype='object')

# %%
categoricals = ['schedule_week', 'team_home', 'team_away']
dummy_cats = pd.get_dummies(prep_data[categoricals])
# display(dummy_cats)

prep_data = pd.concat([prep_data, dummy_cats], axis=1)
prep_data.drop(categoricals, axis=1, inplace= True)

# %% [markdown]
# ## Modeling

# %%
# Split data
y = prep_data['label']
X = prep_data.drop(['label'], axis=1)
print(len(X.columns))
X.columns
# Out:
# 87
# Index(['playoff', 'schedule_week_1', 'schedule_week_10', 'schedule_week_11',
#        'schedule_week_12', 'schedule_week_13', 'schedule_week_14',
#        'schedule_week_15', 'schedule_week_16', 'schedule_week_17',
#        'schedule_week_18', 'schedule_week_2', 'schedule_week_3',
#        'schedule_week_4', 'schedule_week_5', 'schedule_week_6',
#        'schedule_week_7', 'schedule_week_8', 'schedule_week_9',
#        'schedule_week_conference', 'schedule_week_division',
#        'schedule_week_superbowl', 'schedule_week_wildcard',
#        'team_home_Arizona Cardinals', 'team_home_Atlanta Falcons',
#        'team_home_Baltimore Ravens', 'team_home_Buffalo Bills',
#        'team_home_Carolina Panthers', 'team_home_Chicago Bears',
#        'team_home_Cincinnati Bengals', 'team_home_Cleveland Browns',
#        'team_home_Dallas Cowboys', 'team_home_Denver Broncos',
#        'team_home_Detroit Lions', 'team_home_Green Bay Packers',
#        'team_home_Houston Texans', 'team_home_Indianapolis Colts',
#        'team_home_Jacksonville Jaguars', 'team_home_Kansas City Chiefs',
#        'team_home_Los Angeles Chargers', 'team_home_Los Angeles Rams',
#        'team_home_Miami Dolphins', 'team_home_Minnesota Vikings',
#        'team_home_New England Patriots', 'team_home_New Orleans Saints',
#        'team_home_New York Giants', 'team_home_New York Jets',
#        'team_home_Oakland Raiders', 'team_home_Philadelphia Eagles',
#        'team_home_Pittsburgh Steelers', 'team_home_San Francisco 49ers',
#        'team_home_Seattle Seahawks', 'team_home_Tampa Bay Buccaneers',
#        'team_home_Tennessee Titans', 'team_home_Washington Redskins',
#        'team_away_Arizona Cardinals', 'team_away_Atlanta Falcons',
#        'team_away_Baltimore Ravens', 'team_away_Buffalo Bills',
#        'team_away_Carolina Panthers', 'team_away_Chicago Bears',
#        'team_away_Cincinnati Bengals', 'team_away_Cleveland Browns',
#        'team_away_Dallas Cowboys', 'team_away_Denver Broncos',
#        'team_away_Detroit Lions', 'team_away_Green Bay Packers',
#        'team_away_Houston Texans', 'team_away_Indianapolis Colts',
#        'team_away_Jacksonville Jaguars', 'team_away_Kansas City Chiefs',
#        'team_away_Los Angeles Chargers', 'team_away_Los Angeles Rams',
#        'team_away_Miami Dolphins', 'team_away_Minnesota Vikings',
#        'team_away_New England Patriots', 'team_away_New Orleans Saints',
#        'team_away_New York Giants', 'team_away_New York Jets',
#        'team_away_Oakland Raiders', 'team_away_Philadelphia Eagles',
#        'team_away_Pittsburgh Steelers', 'team_away_San Francisco 49ers',
#        'team_away_Seattle Seahawks', 'team_away_Tampa Bay Buccaneers',
#        'team_away_Tennessee Titans', 'team_away_Washington Redskins'],
#       dtype='object')

# %%
# Split data train test data 80-20
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=30113331, shuffle=True)

# %%
X_train.shape[1]
# Out:
# 87

# %%
''' Build Architecture of ANN '''
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow import keras
from keras.callbacks import ModelCheckpoint

model = tf.keras.Sequential([
    layers.Dense(100, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               8800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 8,901
# Trainable params: 8,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', 
            loss='binary_crossentropy', 
            metrics=['accuracy'])

filepath="checkpoints/weights-checkpoint-{epoch:02d}-{accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', mode='max',
                             verbose=1, save_best_only=True, save_weights_only=True )
callbacks_list = [checkpoint]

# Fit the model
# model_history = model.fit(X_train, y_train, epochs=50, callbacks=callbacks_list, verbose=2)
# model_score = model.evaluate(X_test, y_test)

# Whole dataset
model_history = model.fit(X_train, y_train, epochs=50, callbacks=callbacks_list, validation_split=0.2, verbose=2)
model_score = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/50
# 214/214 - 1s - loss: 0.6800 - accuracy: 0.5726 - val_loss: 0.6825 - val_accuracy: 0.5612
#
# Epoch 00001: accuracy improved from -inf to 0.57258, saving model to checkpoints\weights-checkpoint-01-0.5726.hdf5
# Epoch 2/50
# 214/214 - 1s - loss: 0.6645 - accuracy: 0.5988 - val_loss: 0.6789 - val_accuracy: 0.5589
#
# Epoch 00002: accuracy improved from 0.57258 to 0.59880, saving model to checkpoints\weights-checkpoint-02-0.5988.hdf5
# Epoch 3/50
# 214/214 - 0s - loss: 0.6575 - accuracy: 0.6151 - val_loss: 0.6837 - val_accuracy: 0.5636
#
# Epoch 00003: accuracy improved from 0.59880 to 0.61506, saving model to checkpoints\weights-checkpoint-03-0.6151.hdf5
# Epoch 4/50
# 214/214 - 0s - loss: 0.6528 - accuracy: 0.6212 - val_loss: 0.6821 - val_accuracy: 0.5688
#
# Epoch 00004: accuracy improved from 0.61506 to 0.62121, saving model to checkpoints\weights-checkpoint-04-0.6212.hdf5
# Epoch 5/50
# 214/214 - 0s - loss: 0.6475 - accuracy: 0.6269 - val_loss: 0.6830 - val_accuracy: 0.5647
#
# Epoch 00005: accuracy improved from 0.62121 to 0.62692, saving model to checkpoints\weights-checkpoint-05-0.6269.hdf5
# Epoch 6/50
# 214/214 - 0s - loss: 0.6425 - accuracy: 0.6370 - val_loss: 0.6866 - val_accuracy: 0.5618
#
# Epoch 00006: accuracy improved from 0.62692 to 0.63703, saving model to checkpoints\weights-checkpoint-06-0.6370.hdf5
# Epoch 7/50
# 214/214 - 0s - loss: 0.6367 - accuracy: 0.6435 - val_loss: 0.6842 - val_accuracy: 0.5723
#
# Epoch 00007: accuracy improved from 0.63703 to 0.64347, saving model to checkpoints\weights-checkpoint-07-0.6435.hdf5
# Epoch 8/50
# 214/214 - 0s - loss: 0.6305 - accuracy: 0.6486 - val_loss: 0.6934 - val_accuracy: 0.5659
#
# Epoch 00008: accuracy improved from 0.64347 to 0.64860, saving model to checkpoints\weights-checkpoint-08-0.6486.hdf5
# Epoch 9/50
# 214/214 - 0s - loss: 0.6244 - accuracy: 0.6613 - val_loss: 0.6853 - val_accuracy: 0.5718
#
# Epoch 00009: accuracy improved from 0.64860 to 0.66134, saving model to checkpoints\weights-checkpoint-09-0.6613.hdf5
# Epoch 10/50
# 214/214 - 0s - loss: 0.6172 - accuracy: 0.6685 - val_loss: 0.6892 - val_accuracy: 0.5688
#
# Epoch 00010: accuracy improved from 0.66134 to 0.66852, saving model to checkpoints\weights-checkpoint-10-0.6685.hdf5
# Epoch 11/50
# 214/214 - 0s - loss: 0.6099 - accuracy: 0.6804 - val_loss: 0.6912 - val_accuracy: 0.5677
#
# Epoch 00011: accuracy improved from 0.66852 to 0.68039, saving model to checkpoints\weights-checkpoint-11-0.6804.hdf5
# Epoch 12/50
# 214/214 - 0s - loss: 0.6018 - accuracy: 0.6879 - val_loss: 0.6985 - val_accuracy: 0.5659
#
# Epoch 00012: accuracy improved from 0.68039 to 0.68786, saving model to checkpoints\weights-checkpoint-12-0.6879.hdf5
# Epoch 13/50
# 214/214 - 0s - loss: 0.5947 - accuracy: 0.6879 - val_loss: 0.6982 - val_accuracy: 0.5624
#
# Epoch 00013: accuracy did not improve from 0.68786
# Epoch 14/50
# 214/214 - 0s - loss: 0.5860 - accuracy: 0.6968 - val_loss: 0.7048 - val_accuracy: 0.5583
#
# Epoch 00014: accuracy improved from 0.68786 to 0.69679, saving model to checkpoints\weights-checkpoint-14-0.6968.hdf5
# Epoch 15/50
# 214/214 - 0s - loss: 0.5796 - accuracy: 0.6996 - val_loss: 0.7095 - val_accuracy: 0.5647
#
# Epoch 00015: accuracy improved from 0.69679 to 0.69958, saving model to checkpoints\weights-checkpoint-15-0.6996.hdf5
# Epoch 16/50
# 214/214 - 0s - loss: 0.5717 - accuracy: 0.7103 - val_loss: 0.7076 - val_accuracy: 0.5659
#
# Epoch 00016: accuracy improved from 0.69958 to 0.71027, saving model to checkpoints\weights-checkpoint-16-0.7103.hdf5
# Epoch 17/50
# 214/214 - 0s - loss: 0.5653 - accuracy: 0.7120 - val_loss: 0.7144 - val_accuracy: 0.5636
#
# Epoch 00017: accuracy improved from 0.71027 to 0.71203, saving model to checkpoints\weights-checkpoint-17-0.7120.hdf5
# Epoch 18/50
# 214/214 - 0s - loss: 0.5587 - accuracy: 0.7161 - val_loss: 0.7152 - val_accuracy: 0.5665
#
# Epoch 00018: accuracy improved from 0.71203 to 0.71613, saving model to checkpoints\weights-checkpoint-18-0.7161.hdf5
# Epoch 19/50
# 214/214 - 0s - loss: 0.5520 - accuracy: 0.7243 - val_loss: 0.7207 - val_accuracy: 0.5641
#
# Epoch 00019: accuracy improved from 0.71613 to 0.72433, saving model to checkpoints\weights-checkpoint-19-0.7243.hdf5
# Epoch 20/50
# 214/214 - 0s - loss: 0.5463 - accuracy: 0.7299 - val_loss: 0.7251 - val_accuracy: 0.5647
#
# Epoch 00020: accuracy improved from 0.72433 to 0.72990, saving model to checkpoints\weights-checkpoint-20-0.7299.hdf5
# Epoch 21/50
# 214/214 - 0s - loss: 0.5405 - accuracy: 0.7293 - val_loss: 0.7334 - val_accuracy: 0.5706
#
# Epoch 00021: accuracy did not improve from 0.72990
# Epoch 22/50
# 214/214 - 0s - loss: 0.5342 - accuracy: 0.7330 - val_loss: 0.7352 - val_accuracy: 0.5647
#
# Epoch 00022: accuracy improved from 0.72990 to 0.73297, saving model to checkpoints\weights-checkpoint-22-0.7330.hdf5
# Epoch 23/50
# 214/214 - 0s - loss: 0.5291 - accuracy: 0.7377 - val_loss: 0.7487 - val_accuracy: 0.5636
#
# Epoch 00023: accuracy improved from 0.73297 to 0.73766, saving model to checkpoints\weights-checkpoint-23-0.7377.hdf5
# Epoch 24/50
# 214/214 - 0s - loss: 0.5246 - accuracy: 0.7391 - val_loss: 0.7481 - val_accuracy: 0.5571
#
# Epoch 00024: accuracy improved from 0.73766 to 0.73912, saving model to checkpoints\weights-checkpoint-24-0.7391.hdf5
# Epoch 25/50
# 214/214 - 0s - loss: 0.5195 - accuracy: 0.7469 - val_loss: 0.7444 - val_accuracy: 0.5641
#
# Epoch 00025: accuracy improved from 0.73912 to 0.74689, saving model to checkpoints\weights-checkpoint-25-0.7469.hdf5
# Epoch 26/50
# 214/214 - 0s - loss: 0.5150 - accuracy: 0.7485 - val_loss: 0.7571 - val_accuracy: 0.5606
#
# Epoch 00026: accuracy improved from 0.74689 to 0.74850, saving model to checkpoints\weights-checkpoint-26-0.7485.hdf5
# Epoch 27/50
# 214/214 - 0s - loss: 0.5109 - accuracy: 0.7511 - val_loss: 0.7644 - val_accuracy: 0.5636
#
# Epoch 00027: accuracy improved from 0.74850 to 0.75114, saving model to checkpoints\weights-checkpoint-27-0.7511.hdf5
# Epoch 28/50
# 214/214 - 0s - loss: 0.5066 - accuracy: 0.7507 - val_loss: 0.7665 - val_accuracy: 0.5583
#
# Epoch 00028: accuracy did not improve from 0.75114
# Epoch 29/50
# 214/214 - 0s - loss: 0.5012 - accuracy: 0.7604 - val_loss: 0.7816 - val_accuracy: 0.5571
#
# Epoch 00029: accuracy improved from 0.75114 to 0.76036, saving model to checkpoints\weights-checkpoint-29-0.7604.hdf5
# Epoch 30/50
# 214/214 - 0s - loss: 0.4980 - accuracy: 0.7589 - val_loss: 0.7763 - val_accuracy: 0.5507
#
# Epoch 00030: accuracy did not improve from 0.76036
# Epoch 31/50
# 214/214 - 0s - loss: 0.4945 - accuracy: 0.7608 - val_loss: 0.7841 - val_accuracy: 0.5583
#
# Epoch 00031: accuracy improved from 0.76036 to 0.76080, saving model to checkpoints\weights-checkpoint-31-0.7608.hdf5
# Epoch 32/50
# 214/214 - 0s - loss: 0.4894 - accuracy: 0.7661 - val_loss: 0.7837 - val_accuracy: 0.5595
#
# Epoch 00032: accuracy improved from 0.76080 to 0.76608, saving model to checkpoints\weights-checkpoint-32-0.7661.hdf5
# Epoch 33/50
# 214/214 - 0s - loss: 0.4859 - accuracy: 0.7656 - val_loss: 0.7937 - val_accuracy: 0.5571
#
# Epoch 00033: accuracy did not improve from 0.76608
# Epoch 34/50
# 214/214 - 0s - loss: 0.4822 - accuracy: 0.7672 - val_loss: 0.8009 - val_accuracy: 0.5548
#
# Epoch 00034: accuracy improved from 0.76608 to 0.76725, saving model to checkpoints\weights-checkpoint-34-0.7672.hdf5
# Epoch 35/50
# 214/214 - 0s - loss: 0.4791 - accuracy: 0.7686 - val_loss: 0.8051 - val_accuracy: 0.5636
#
# Epoch 00035: accuracy improved from 0.76725 to 0.76857, saving model to checkpoints\weights-checkpoint-35-0.7686.hdf5
# Epoch 36/50
# 214/214 - 0s - loss: 0.4761 - accuracy: 0.7703 - val_loss: 0.8059 - val_accuracy: 0.5612
#
# Epoch 00036: accuracy improved from 0.76857 to 0.77032, saving model to checkpoints\weights-checkpoint-36-0.7703.hdf5
# Epoch 37/50
# 214/214 - 0s - loss: 0.4718 - accuracy: 0.7738 - val_loss: 0.8125 - val_accuracy: 0.5466
#
# Epoch 00037: accuracy improved from 0.77032 to 0.77384, saving model to checkpoints\weights-checkpoint-37-0.7738.hdf5
# Epoch 38/50
# 214/214 - 0s - loss: 0.4692 - accuracy: 0.7759 - val_loss: 0.8197 - val_accuracy: 0.5548
#
# Epoch 00038: accuracy improved from 0.77384 to 0.77589, saving model to checkpoints\weights-checkpoint-38-0.7759.hdf5
# Epoch 39/50
# 214/214 - 0s - loss: 0.4654 - accuracy: 0.7796 - val_loss: 0.8226 - val_accuracy: 0.5548
#
# Epoch 00039: accuracy improved from 0.77589 to 0.77955, saving model to checkpoints\weights-checkpoint-39-0.7796.hdf5
# Epoch 40/50
# 214/214 - 0s - loss: 0.4642 - accuracy: 0.7752 - val_loss: 0.8291 - val_accuracy: 0.5554
# Epoch 00040: accuracy did not improve from 0.77955
# Epoch 41/50
# 214/214 - 0s - loss: 0.4607 - accuracy: 0.7816 - val_loss: 0.8370 - val_accuracy: 0.5495
#
# Epoch 00041: accuracy improved from 0.77955 to 0.78160, saving model to checkpoints\weights-checkpoint-41-0.7816.hdf5
# Epoch 42/50
# 214/214 - 0s - loss: 0.4571 - accuracy: 0.7845 - val_loss: 0.8475 - val_accuracy: 0.5431
#
# Epoch 00042: accuracy improved from 0.78160 to 0.78453, saving model to checkpoints\weights-checkpoint-42-0.7845.hdf5
# Epoch 43/50
# 214/214 - 0s - loss: 0.4547 - accuracy: 0.7835 - val_loss: 0.8487 - val_accuracy: 0.5554
#
# Epoch 00043: accuracy did not improve from 0.78453
# Epoch 44/50
# 214/214 - 0s - loss: 0.4522 - accuracy: 0.7872 - val_loss: 0.8552 - val_accuracy: 0.5542
#
# Epoch 00044: accuracy improved from 0.78453 to 0.78717, saving model to checkpoints\weights-checkpoint-44-0.7872.hdf5
# Epoch 45/50
# 214/214 - 0s - loss: 0.4494 - accuracy: 0.7869 - val_loss: 0.8563 - val_accuracy: 0.5513
#
# Epoch 00045: accuracy did not improve from 0.78717
# Epoch 46/50
# 214/214 - 0s - loss: 0.4476 - accuracy: 0.7879 - val_loss: 0.8593 - val_accuracy: 0.5483
#
# Epoch 00046: accuracy improved from 0.78717 to 0.78790, saving model to checkpoints\weights-checkpoint-46-0.7879.hdf5
# Epoch 47/50
# 214/214 - 0s - loss: 0.4447 - accuracy: 0.7888 - val_loss: 0.8607 - val_accuracy: 0.5583
#
# Epoch 00047: accuracy improved from 0.78790 to 0.78878, saving model to checkpoints\weights-checkpoint-47-0.7888.hdf5
# Epoch 48/50
# 214/214 - 0s - loss: 0.4428 - accuracy: 0.7911 - val_loss: 0.8678 - val_accuracy: 0.5495
#
# Epoch 00048: accuracy improved from 0.78878 to 0.79112, saving model to checkpoints\weights-checkpoint-48-0.7911.hdf5
# Epoch 49/50
# 214/214 - 0s - loss: 0.4399 - accuracy: 0.7911 - val_loss: 0.8822 - val_accuracy: 0.5618
#
# Epoch 00049: accuracy did not improve from 0.79112
# Epoch 50/50
# 214/214 - 0s - loss: 0.4377 - accuracy: 0.7882 - val_loss: 0.8732 - val_accuracy: 0.5425
#
# Epoch 00050: accuracy did not improve from 0.79112
# 67/67 [==============================] - 0s 789us/step - loss: 0.8852 - accuracy: 0.5394

# %% [markdown]
# ## Plot ephoc's scores and save model to disk

# %%
# Plot Loss Score and Accuracy
import matplotlib.pyplot as plt
pd.DataFrame(model_history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# Save model
model.save('./nfl_predictor.model')
# Out:
# INFO:tensorflow:Assets written to: ./nfl_predictor.model\assets

# %% [markdown]
# ## Load model and weights from disk for prediction

# %%
# checkpoints\weights-checkpoint-49-0.7785.hdf5
# nfl_predictor.model

# nfl_predictor_model = keras.models.load_model('nfl_predictor.model')
# model.load_weights('weights_best.hdf5')
# model.compile(loss='binary_crossentropy', optimizer='adam')

# x_sample = X.iloc[11].copy()
# y_sample = y[11]
# print(x_sample)
# print(y_sample)
# print(x_sample.shape[0])

# x_sample = x_sample.values.reshape(1,x_sample.shape[0])
# y_predict = nfl_predictor_model.predict(x_sample)
# print(1 if y_predict > 0.5 else 0)
